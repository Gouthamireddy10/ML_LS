# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Rescaling
from tensorflow.keras import Input
from tensorflow.keras.optimizers import Adam

# %%
# Load dataset from the directory
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    r'C:\Users\tudig\Downloads\homer_bart',
    image_size=(64, 64),
    label_mode="binary"
)
# Out:
# Found 269 files belonging to 2 classes.

# %%
# Split the dataset into training and testing sets
train_data = dataset.take(8)
test_data = dataset.skip(8)
train_data = train_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_data = test_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# Preprocessing layer
preprocess = tf.keras.Sequential(
    [Rescaling(1./255)]  # Normalize the images to the range [0, 1]
)

# %%
# Build the model
model = tf.keras.Sequential()
model.add(Input((64, 64, 3)))
model.add(preprocess)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Sigmoid activation for binary classification

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),  # Binary cross-entropy loss
              metrics=['accuracy'])

# Train the model
history = model.fit(train_data,
                    epochs=50,  # Adjust the number of epochs as needed
                    verbose=1,
                    validation_data=test_data)

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(test_data, verbose=0)
print(f'Test accuracy: {test_acc:.2f}')
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.6094 - loss: 3.5951 - val_accuracy: 0.4615 - val_loss: 0.9867
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.5522 - loss: 2.4093 - val_accuracy: 0.5385 - val_loss: 1.1990
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.6158 - loss: 1.9778 - val_accuracy: 0.5385 - val_loss: 1.6583
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.6488 - loss: 1.1741 - val_accuracy: 0.6154 - val_loss: 0.8223
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.7605 - loss: 0.5081 - val_accuracy: 0.7692 - val_loss: 0.6510
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.7207 - loss: 0.5502 - val_accuracy: 0.6923 - val_loss: 0.4748
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.7245 - loss: 0.6311 - val_accuracy: 0.6154 - val_loss: 0.4333
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.7364 - loss: 0.5094 - val_accuracy: 0.7692 - val_loss: 0.5662
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.7375 - loss: 0.6283 - val_accuracy: 0.5385 - val_loss: 1.1800
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.7206 - loss: 0.6575 - val_accuracy: 0.7692 - val_loss: 0.3627
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.7350 - loss: 0.5300 - val_accuracy: 0.7692 - val_loss: 0.3454
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.8187 - loss: 0.3877 - val_accuracy: 0.8462 - val_loss: 0.3480
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.7717 - loss: 0.4471 - val_accuracy: 0.8462 - val_loss: 0.3193
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.8300 - loss: 0.3864 - val_accuracy: 0.7692 - val_loss: 0.3449
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.7931 - loss: 0.4057 - val_accuracy: 0.7692 - val_loss: 0.4794
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.8351 - loss: 0.3638 - val_accuracy: 0.9231 - val_loss: 0.2389
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.8985 - loss: 0.2752 - val_accuracy: 0.7692 - val_loss: 0.4428
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.8502 - loss: 0.3175 - val_accuracy: 0.7692 - val_loss: 0.2595
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9163 - loss: 0.2287 - val_accuracy: 0.9231 - val_loss: 0.2018
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.8868 - loss: 0.2937 - val_accuracy: 0.8462 - val_loss: 0.2575
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.8514 - loss: 0.3241 - val_accuracy: 0.6923 - val_loss: 0.4746
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.8384 - loss: 0.3338 - val_accuracy: 0.7692 - val_loss: 0.2695
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9190 - loss: 0.1844 - val_accuracy: 1.0000 - val_loss: 0.1402
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9283 - loss: 0.1776 - val_accuracy: 1.0000 - val_loss: 0.1330
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9591 - loss: 0.1461 - val_accuracy: 0.9231 - val_loss: 0.1406
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9811 - loss: 0.1224 - val_accuracy: 1.0000 - val_loss: 0.1318
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.9702 - loss: 0.1268 - val_accuracy: 1.0000 - val_loss: 0.0962
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9719 - loss: 0.1035 - val_accuracy: 1.0000 - val_loss: 0.1038
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 1.0000 - loss: 0.0805 - val_accuracy: 1.0000 - val_loss: 0.0882
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9953 - loss: 0.0694 - val_accuracy: 1.0000 - val_loss: 0.0650
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 1.0000 - loss: 0.0536 - val_accuracy: 1.0000 - val_loss: 0.0944
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9837 - loss: 0.0788 - val_accuracy: 1.0000 - val_loss: 0.0475
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 1.0000 - loss: 0.0384 - val_accuracy: 1.0000 - val_loss: 0.0368
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 1.0000 - loss: 0.0293 - val_accuracy: 1.0000 - val_loss: 0.0614
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 1.0000 - loss: 0.0294 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 1.0000 - loss: 0.0175 - val_accuracy: 1.0000 - val_loss: 0.0171
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 1.0000 - loss: 0.0165 - val_accuracy: 1.0000 - val_loss: 0.0092
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 1.0000 - loss: 0.0226 - val_accuracy: 1.0000 - val_loss: 0.0174
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.8909 - loss: 0.4543 - val_accuracy: 1.0000 - val_loss: 0.0462
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9562 - loss: 0.1234 - val_accuracy: 1.0000 - val_loss: 0.0702
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.9926 - loss: 0.0688 - val_accuracy: 1.0000 - val_loss: 0.0564
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.9936 - loss: 0.0499 - val_accuracy: 1.0000 - val_loss: 0.0358
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9963 - loss: 0.0559 - val_accuracy: 1.0000 - val_loss: 0.0150
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9755 - loss: 0.0737 - val_accuracy: 1.0000 - val_loss: 0.0195
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.9216 - loss: 0.2163 - val_accuracy: 0.6154 - val_loss: 2.6745
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.6314 - loss: 1.3868 - val_accuracy: 0.7692 - val_loss: 0.3393
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.8670 - loss: 0.2338 - val_accuracy: 1.0000 - val_loss: 0.0788
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9450 - loss: 0.1224 - val_accuracy: 0.7692 - val_loss: 0.3764
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9143 - loss: 0.2128 - val_accuracy: 0.9231 - val_loss: 0.1951
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9339 - loss: 0.1487 - val_accuracy: 1.0000 - val_loss: 0.0451
# Test accuracy: 1.00
